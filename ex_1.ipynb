# %%
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import csv
import math

# %%
l = 2**8
L = 24

def t(m):
    return (2**L)/(m*l)


def PH(m):
    a = (-math.sqrt((2*m*l**2)/2**L))
    b = math.exp(math.sqrt((2*m*t(m)**2)/2**L))-1
    c = math.exp(math.sqrt((2*m*t(m)**2)/2**L))+1
    ph = 1 -math.exp(a*(b/c))
    return ph

# %%
result = []
for i in range(1,int(2**L/l)):
    result.append(PH(i))

# %%
plt.plot(result)
plt.xlim(right=1000)  
plt.xlim(left=0)
# Out:
# (0, 1000.0)

# %%
def Pr(m, t, l):
    out = 1-((2/(2+((m*t*t)/(2**l)))**2))
    return out

# %%
resultRainbowTables = []
for t in range(1,int(2**24/24)):
    resultRainbowTables.append(Pr(2**8,t, 24))

# %%
plt.plot(resultRainbowTables)
plt.xlim(right=1000)  
plt.xlim(left=0)
# Out:
# (0, 1000.0)

# %% [markdown]
# #### Coverage

# %%
resultNEW = []
for i in result:
    resultNEW.append(i*(2**L))

# %%
plt.plot(resultNEW)
plt.xlim(right=1000)  
plt.xlim(left=0)
# Out:
# (0, 1000.0)

# %%
resultRainbowTablesNEW = []
for i in resultRainbowTables:
    resultRainbowTablesNEW.append(i*(2**L))


plt.plot(resultRainbowTablesNEW)
plt.xlim(right=1000)  
plt.xlim(left=0)
# Out:
# (0, 1000.0)

# %% [markdown]
# #### Pandas - import and plot

# %%
uniqueCounts = []
col_name= [i for i in range(1,65536)]
row_count = 10
for chunk in pd.read_csv("exercise3/cmake-build-debug/hellman.csv",  names=col_name, chunksize=row_count): 
    print(chunk.head()) # process it
    
    
    
fix t max

coverage is unique values

    break
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-e8783da746fb> in <module>
#       2 col_name= [i for i in range(1,65536)]
#       3 row_count = 10
# ----> 4 for chunk in pd.read_csv("exercise3/cmake-build-debug/hellman.csv",  names=col_name, chunksize=row_count):
#       5     print(chunk.head()) # process it
#       6
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'exercise3/cmake-build-debug/hellman.csv' does not exist: b'exercise3/cmake-build-debug/hellman.csv'

# %%
import numpy as np
import pandas as pd

coverage_values = []
NUMBER_OF_TABLES = 1
for i in range(0,NUMBER_OF_TABLES):
    print(i)
    df = pd.read_csv('exercise3/rainbow' + str(i) + '.csv')
    data = df.values
    print(data)
    coverage_values.append(len(np.unique(data)))
# Out:
# 0
# [[         2    1677402 4293292337 ... 4292547991    8179173    2480535]
#  [         3    3132629    6512412 ...    4483618    6119104    3109381]
#  [         4    5514154 4287148282 ... 4292692777    1453498      98129]
#  ...
#  [       254 4290643404 4292540491 ... 4294055103    1749023 4294459534]
#  [       255    7183826 4294451742 ... 4294305211    3283405 4290447459]
#  [       256    6260863    1893873 ...    4463306    5567052    1471594]]

# %%
coverage_values
# Out:
# [152324]

# %%
import numpy as np
import pandas as pd


coverage_values = []
NUMBER_OF_TABLES = 1
for i in range(0,NUMBER_OF_TABLES):
    print(i)
    df = pd.read_csv('exercise3/cmake-build-debug/hellman' + str(i) + '.csv')
    data = df.values
    print(data)
    coverage_values.append(len(np.unique(data)))
# Out:
# 0
# [[2.00000000e+00 4.29359653e+09 4.28810584e+09 ... 4.28748387e+09
#   6.66025400e+06            nan]
#  [3.00000000e+00 1.68792200e+06 4.29405053e+09 ... 6.79388500e+06
#   4.30298700e+06            nan]
#  [4.00000000e+00 4.18509500e+06 4.28809842e+09 ... 5.39310500e+06
#   4.28667991e+09            nan]
#  ...
#  [2.54000000e+02 7.76671700e+06 2.01854100e+06 ... 7.38716500e+06
#   4.28801785e+09            nan]
#  [2.55000000e+02 3.96224000e+05 4.06428900e+06 ... 4.29166411e+09
#   6.77702600e+06            nan]
#  [2.56000000e+02 4.28844200e+09 3.04680000e+04 ... 4.29177002e+09
#   4.29461983e+09            nan]]

# %%
import numpy as np
import pandas as pd
 
unique_values = set([])
unique_value_count = []
NUMBER_OF_TABLES = 256
for i in range(0,NUMBER_OF_TABLES):
    if(i%20 == 0):
        print(i)
    df = pd.read_csv('exercise3/rainbow' + str(i) + '.csv')
    data = df.values
    #print(data)
    for j in np.unique(data):
        unique_values.add(j)
    unique_value_count.append(len(unique_values))
# Out:
# 0
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 220
# 240

# %%
c = [i/2**24 for i in unique_value_count]

plt.plot(c)
plt.xlim(right=256)  
plt.xlim(left=0)
# Out:
# (0, 256.0)
