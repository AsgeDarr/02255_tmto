# %%
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import csv
import math

# %%
l = 2**8
L = 24

def t(m):
    return (2**L)/(m*l)


def PH(m):
    a = (-math.sqrt((2*m*l**2)/2**L))
    b = math.exp(math.sqrt((2*m*t(m)**2)/2**L))-1
    c = math.exp(math.sqrt((2*m*t(m)**2)/2**L))+1
    ph = 1 -math.exp(a*(b/c))
    return ph

# %%
result = []
for i in range(1,int(2**L/l)):
    result.append(PH(i))

# %%
plt.plot(result)
plt.xlim(right=1000)  
plt.xlim(left=0)
# Out:
# (0, 1000.0)

# %%
def Pr(m, t, l):
    out = 1-((2/(2+((m*t*t)/(2**l)))**2))
    return out

# %%
resultRainbowTables = []
for t in range(1,int(2**24/24)):
    resultRainbowTables.append(Pr(2**8,t, 24))

# %%
plt.plot(resultRainbowTables)
plt.xlim(right=1000)  
plt.xlim(left=0)
# Out:
# (0, 1000.0)

# %% [markdown]
# #### Coverage

# %%
resultNEW = []
for i in result:
    resultNEW.append(i*(2**L))

# %%
plt.plot(resultNEW)
plt.xlim(right=1000)  
plt.xlim(left=0)
# Out:
# (0, 1000.0)

# %%
resultRainbowTablesNEW = []
for i in resultRainbowTables:
    resultRainbowTablesNEW.append(i*(2**L))


plt.plot(resultRainbowTablesNEW)
plt.xlim(right=1000)  
plt.xlim(left=0)
# Out:
# (0, 1000.0)

# %% [markdown]
# #### Pandas - import and plot

# %% [markdown]
# ## HELLMAN TABLES

# %%
uniqueCounts = []
col_name= [i for i in range(1,1001)]
row_count = 10

#df = pd.read_csv("exercise3/cmake-build-debug/hellman.csv",  names=col_name)
df_clean = pd.read_csv("exercise3/cmake-build-debug/hellman.csv",lineterminator='\n')
df_clean.columns = col_name

# %%
#df_clean

# %%
unique_values_HELLMAN = set([])
unique_value_count_HELLMAN = []
NUMBER_OF_COLUMNS = 1000
for i in range(0,NUMBER_OF_COLUMNS):
    if(i%50 == 0):
        print(i)
    for j in np.unique(df_clean[df_clean.columns[i]]):
        unique_values_HELLMAN.add(j)
    unique_value_count_HELLMAN.append(len(unique_values_HELLMAN))
# Out:
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950

# %%
uniqueHellman = [i/2**24 for i in unique_value_count_HELLMAN]

plt.plot(uniqueHellman)
plt.xlim(right=1000)  
plt.xlim(left=0)
# Out:
# (0, 1000.0)

# %%
plt.plot(uniqueHellman, 'r') # plotting t, a separately 
plt.plot(resultNEW, 'b')
plt.xlim(right=1000)  
plt.xlim(left=0)
plt.show()

# %%
plt.plot(uniqueHellman, 'r')
plt.xlim(right=1000)  
plt.xlim(left=0)
# Out:
# (0, 1000.0)

# %% [markdown]
# ## RAINBOW TABLES

# %%
import numpy as np
import pandas as pd

coverage_values = []
NUMBER_OF_TABLES = 1
for i in range(0,NUMBER_OF_TABLES):
    print(i)
    df = pd.read_csv('exercise3/rainbow' + str(i) + '.csv')
    data = df.values
    print(data)
    coverage_values.append(len(np.unique(data)))

# %%
coverage_values

# %%
import numpy as np
import pandas as pd
 
unique_values = set([])
unique_value_count = []
NUMBER_OF_TABLES = 256
for i in range(0,NUMBER_OF_TABLES):
    if(i%20 == 0):
        print(i)
    df = pd.read_csv('exercise3/rainbow' + str(i) + '.csv')
    data = df.values
    #print(data)
    for j in np.unique(data):
        unique_values.add(j)
    unique_value_count.append(len(unique_values))

# %%
c = [i/2**24 for i in unique_value_count]

plt.plot(c)
plt.xlim(right=256)  
plt.xlim(left=0)
